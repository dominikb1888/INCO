# %%
import pandas as pd

# %%
countries = pd.read_json('countries.json')
countries.to_dict(orient = 'records')
# Out:
# [{'value': 2, 'key': 'Argentina'},
#  {'value': 4, 'key': 'Australia'},
#  {'value': 7, 'key': 'Austria'},
#  {'value': 5, 'key': 'Belgium'},
#  {'value': 9, 'key': 'Canada'},
#  {'value': 1, 'key': 'China'},
#  {'value': 1, 'key': 'Czechoslovakia'},
#  {'value': 9, 'key': 'Denmark'},
#  {'value': 1, 'key': 'Finland'},
#  {'value': 38, 'key': 'France'},
#  {'value': 1, 'key': 'Germany'},
#  {'value': 71, 'key': 'Germany'},
#  {'value': 1, 'key': 'Hungary'},
#  {'value': 1, 'key': 'India'},
#  {'value': 1, 'key': 'Ireland'},
#  {'value': 5, 'key': 'Israel'},
#  {'value': 7, 'key': 'Italy'},
#  {'value': 17, 'key': 'Japan'},
#  {'value': 5, 'key': 'Norway'},
#  {'value': 1, 'key': 'Portugal'},
#  {'value': 3, 'key': 'Russia'},
#  {'value': 1, 'key': 'Spain'},
#  {'value': 17, 'key': 'Sweden'},
#  {'value': 24, 'key': 'Switzerland'},
#  {'value': 1, 'key': 'Tunisia'},
#  {'value': 379, 'key': 'USA'},
#  {'value': 9, 'key': 'USSR'},
#  {'value': 93, 'key': 'United'},
#  {'value': 10, 'key': 'the'},
#  {'value': 265, 'key': 'null'}]

# %%
codes = pd.read_json("ccodes.json")
codes
# Out:
#                   name alpha-2 alpha-3  country-code     iso_3166-2   region  \
# 0          Afghanistan      AF     AFG             4  ISO 3166-2:AF     Asia
# 1        Åland Islands      AX     ALA           248  ISO 3166-2:AX   Europe
# 2              Albania      AL     ALB             8  ISO 3166-2:AL   Europe
# 3              Algeria      DZ     DZA            12  ISO 3166-2:DZ   Africa
# 4       American Samoa      AS     ASM            16  ISO 3166-2:AS  Oceania
# ..                 ...     ...     ...           ...            ...      ...
# 244  Wallis and Futuna      WF     WLF           876  ISO 3166-2:WF  Oceania
# 245     Western Sahara      EH     ESH           732  ISO 3166-2:EH   Africa
# 246              Yemen      YE     YEM           887  ISO 3166-2:YE     Asia
# 247             Zambia      ZM     ZMB           894  ISO 3166-2:ZM   Africa
# 248           Zimbabwe      ZW     ZWE           716  ISO 3166-2:ZW   Africa
#
#              sub-region intermediate-region region-code sub-region-code  \
# 0         Southern Asia                             142             034
# 1       Northern Europe                             150             154
# 2       Southern Europe                             150             039
# 3       Northern Africa                             002             015
# 4             Polynesia                             009             061
# ..                  ...                 ...         ...             ...
# 244           Polynesia                             009             061
# 245     Northern Africa                             002             015
# 246        Western Asia                             142             145
# 247  Sub-Saharan Africa      Eastern Africa         002             202
# 248  Sub-Saharan Africa      Eastern Africa         002             202
#
#     intermediate-region-code
# 0
# 1
# 2
# 3
# 4
# ..                       ...
# 244
# 245
# 246
# 247                      014
# 248                      014
#
# [249 rows x 11 columns]

# %%
cm = [
 {'value': 2, 'key': 'Argentina'},
 {'value': 4, 'key': 'Australia'},
 {'value': 7, 'key': 'Austria'},
 {'value': 5, 'key': 'Belgium'},
 {'value': 9, 'key': 'Canada'},
 {'value': 1, 'key': 'China'},
 {'value': 1, 'key': 'Czechia'},
 {'value': 9, 'key': 'Denmark'},
 {'value': 1, 'key': 'Finland'},
 {'value': 38, 'key': 'France'},
 {'value': 72, 'key': 'Germany'},
 {'value': 1, 'key': 'Hungary'},
 {'value': 1, 'key': 'India'},
 {'value': 1, 'key': 'Ireland'},
 {'value': 5, 'key': 'Israel'},
 {'value': 7, 'key': 'Italy'},
 {'value': 17, 'key': 'Japan'},
 {'value': 5, 'key': 'Norway'},
 {'value': 1, 'key': 'Portugal'},
 {'value': 3, 'key': 'Russia'},
 {'value': 1, 'key': 'Spain'},
 {'value': 17, 'key': 'Sweden'},
 {'value': 24, 'key': 'Switzerland'},
 {'value': 1, 'key': 'Tunisia'},
 {'value': 379, 'key': 'United States of America'},
 {'value': 9, 'key': 'Russian Federation'},
 {'value': 93, 'key': 'United Kingdom of Great Britain and Northern Ireland'},
 {'value': 10, 'key': 'Netherlands'},
 {'value': 265, 'key': 'null'}
]

cm = {c['key']:c['value'] for c in cm}
len(cm)
# Out:
# 28

# %%
codes['prizes_won'] = codes.name.map(cm)
codes.sort_values('prizes_won', ascending=False)
# Out:
#                          name alpha-2 alpha-3  country-code     iso_3166-2  \
# 235  United States of America      US     USA           840  ISO 3166-2:US
# 83                    Germany      DE     DEU           276  ISO 3166-2:DE
# 76                     France      FR     FRA           250  ISO 3166-2:FR
# 215               Switzerland      CH     CHE           756  ISO 3166-2:CH
# 112                     Japan      JP     JPN           392  ISO 3166-2:JP
# ..                        ...     ...     ...           ...            ...
# 244         Wallis and Futuna      WF     WLF           876  ISO 3166-2:WF
# 245            Western Sahara      EH     ESH           732  ISO 3166-2:EH
# 246                     Yemen      YE     YEM           887  ISO 3166-2:YE
# 247                    Zambia      ZM     ZMB           894  ISO 3166-2:ZM
# 248                  Zimbabwe      ZW     ZWE           716  ISO 3166-2:ZW
#
#        region          sub-region intermediate-region region-code  \
# 235  Americas    Northern America                             019
# 83     Europe      Western Europe                             150
# 76     Europe      Western Europe                             150
# 215    Europe      Western Europe                             150
# 112      Asia        Eastern Asia                             142
# ..        ...                 ...                 ...         ...
# 244   Oceania           Polynesia                             009
# 245    Africa     Northern Africa                             002
# 246      Asia        Western Asia                             142
# 247    Africa  Sub-Saharan Africa      Eastern Africa         002
# 248    Africa  Sub-Saharan Africa      Eastern Africa         002
#
#     sub-region-code intermediate-region-code  prizes_won
# 235             021                                379.0
# 83              155                                 72.0
# 76              155                                 38.0
# 215             155                                 24.0
# 112             030                                 17.0
# ..              ...                      ...         ...
# 244             061                                  NaN
# 245             015                                  NaN
# 246             145                                  NaN
# 247             202                      014         NaN
# 248             202                      014         NaN
#
# [249 rows x 12 columns]

# %%
set(codes.name[codes.prizes_won.notnull()]).difference(set(cm.keys()))
# Out:
# set()

# %%
set(cm.keys()) - set(codes.name[codes.prizes_won.notnull()])
# Out:
# {'Czech Republic', 'Russia', 'United Kingdom', 'null'}

# %%
codes[codes.name.str.contains("United Kingdom")]
# Out:
#                                                   name alpha-2 alpha-3  \
# 234  United Kingdom of Great Britain and Northern I...      GB     GBR
#
#      country-code     iso_3166-2  region       sub-region intermediate-region  \
# 234           826  ISO 3166-2:GB  Europe  Northern Europe
#
#     region-code sub-region-code intermediate-region-code  prizes_won
# 234         150             154                                  NaN
