# %%
import pandas as pd
import json

# %%
df = pd.read_json('github_repos_with_users.json')

# %%
df.dtypes
# Out:
# mentionableUsers    object
# name                object
# updatedAt           object
# url                 object
# dtype: object

# %%
dir(df.name.str)
# Out:
# ['__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__frozen',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_data',
#  '_doc_args',
#  '_freeze',
#  '_get_series_list',
#  '_index',
#  '_inferred_dtype',
#  '_is_categorical',
#  '_is_string',
#  '_name',
#  '_orig',
#  '_parent',
#  '_validate',
#  '_wrap_result',
#  'capitalize',
#  'casefold',
#  'cat',
#  'center',
#  'contains',
#  'count',
#  'decode',
#  'encode',
#  'endswith',
#  'extract',
#  'extractall',
#  'find',
#  'findall',
#  'fullmatch',
#  'get',
#  'get_dummies',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isdecimal',
#  'isdigit',
#  'islower',
#  'isnumeric',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'len',
#  'ljust',
#  'lower',
#  'lstrip',
#  'match',
#  'normalize',
#  'pad',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'repeat',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rpartition',
#  'rsplit',
#  'rstrip',
#  'slice',
#  'slice_replace',
#  'split',
#  'startswith',
#  'strip',
#  'swapcase',
#  'title',
#  'translate',
#  'upper',
#  'wrap',
#  'zfill']

# %%
df.name.str.split('-', expand=True)
# Out:
#      0   1           2                 3                 4        5
# 0   02  02    triangle     TobiasLechner              None     None
# 1   01  02        leap              Sara               256     None
# 2   01  01       hello             world              Sara      256
# 3   01  02        leap           Elyastk              None     None
# 4   01  01       hello             world           Elyastk     None
# 5   01  01       hello             world    Favourmekowulu     None
# 6   01  01       hello             world           Nazek23     None
# 7   01  03  gigasecond  DainaBulmeistere              None     None
# 8   01  01       hello             world        RawanAtoui     None
# 9   01  02        leap           Piromya       Chaekratoke     None
# 10  01  04      grains        maryam0109              None     None
# 11  01  03  gigasecond        maryam0109              None     None
# 12  01  02        leap    Alexandra18636              None     None
# 13  01  03  gigasecond           mm13177              None     None
# 14  01  02        leap           mm13177              None     None
# 15  01  01       hello             world        Christabel    Oreva
# 16  01  02        leap     TobiasLechner              None     None
# 17  01  04      grains           shreeja           shreeja     None
# 18  01  03  gigasecond           shreeja           shreeja     None
# 19  01  01       hello             world   FadyAbdelmaseeh     None
# 20  01  01       hello             world              reem       ab
# 21  01  02        leap       marina20158              None     None
# 22  01  03  gigasecond            wijube              None     None
# 23  01  02        leap            wijube              None     None
# 24  01  01       hello             world  DainaBulmeistere     None
# 25  01  02        leap           shreeja           shreeja     None
# 26  01  03  gigasecond              Jane            Amollo     None
# 27  01  01       hello             world   FadyRaafatKamel     None
# 28  01  01       hello             world           shreeja  shreeja
# 29  01  01       hello             world      atulmallik14     None

# %%
df
# Out:
#                                      mentionableUsers  \
# 0   [{'id': 'MDQ6VXNlcjI4OTYxMg==', 'login': 'domi...
# 1   [{'id': 'MDQ6VXNlcjI4OTYxMg==', 'login': 'domi...
# 2   [{'id': 'MDQ6VXNlcjI4OTYxMg==', 'login': 'domi...
# 3   [{'id': 'MDQ6VXNlcjI4OTYxMg==', 'login': 'domi...
# 4   [{'id': 'MDQ6VXNlcjI4OTYxMg==', 'login': 'domi...
# 5   [{'id': 'MDQ6VXNlcjI4OTYxMg==', 'login': 'domi...
# 6   [{'id': 'MDQ6VXNlcjI4OTYxMg==', 'login': 'domi...
# 7   [{'id': 'MDQ6VXNlcjI4OTYxMg==', 'login': 'domi...
# 8   [{'id': 'MDQ6VXNlcjI4OTYxMg==', 'login': 'domi...
# 9   [{'id': 'MDQ6VXNlcjI4OTYxMg==', 'login': 'domi...
# 10  [{'id': 'MDQ6VXNlcjI4OTYxMg==', 'login': 'domi...
# 11  [{'id': 'MDQ6VXNlcjI4OTYxMg==', 'login': 'domi...
# 12  [{'id': 'MDQ6VXNlcjI4OTYxMg==', 'login': 'domi...
# 13  [{'id': 'MDQ6VXNlcjI4OTYxMg==', 'login': 'domi...
# 14  [{'id': 'MDQ6VXNlcjI4OTYxMg==', 'login': 'domi...
# 15  [{'id': 'MDQ6VXNlcjI4OTYxMg==', 'login': 'domi...
# 16  [{'id': 'MDQ6VXNlcjI4OTYxMg==', 'login': 'domi...
# 17  [{'id': 'MDQ6VXNlcjI4OTYxMg==', 'login': 'domi...
# 18  [{'id': 'MDQ6VXNlcjI4OTYxMg==', 'login': 'domi...
# 19  [{'id': 'MDQ6VXNlcjI4OTYxMg==', 'login': 'domi...
# 20  [{'id': 'MDQ6VXNlcjI4OTYxMg==', 'login': 'domi...
# 21  [{'id': 'MDQ6VXNlcjI4OTYxMg==', 'login': 'domi...
# 22  [{'id': 'MDQ6VXNlcjI4OTYxMg==', 'login': 'domi...
# 23  [{'id': 'MDQ6VXNlcjI4OTYxMg==', 'login': 'domi...
# 24  [{'id': 'MDQ6VXNlcjI4OTYxMg==', 'login': 'domi...
# 25  [{'id': 'MDQ6VXNlcjI4OTYxMg==', 'login': 'domi...
# 26  [{'id': 'MDQ6VXNlcjI4OTYxMg==', 'login': 'domi...
# 27  [{'id': 'MDQ6VXNlcjI4OTYxMg==', 'login': 'domi...
# 28  [{'id': 'MDQ6VXNlcjI4OTYxMg==', 'login': 'domi...
# 29  [{'id': 'MDQ6VXNlcjI4OTYxMg==', 'login': 'domi...
#
#                                   name             updatedAt  \
# 0         02-02-triangle-TobiasLechner  2022-10-17T11:16:32Z
# 1                  01-02-leap-Sara-256  2022-10-17T00:52:45Z
# 2           01-01-hello-world-Sara-256  2022-10-11T09:08:01Z
# 3                   01-02-leap-Elyastk  2022-10-16T21:35:14Z
# 4            01-01-hello-world-Elyastk  2022-10-16T18:35:37Z
# 5     01-01-hello-world-Favourmekowulu  2022-10-16T14:59:16Z
# 6            01-01-hello-world-Nazek23  2022-10-11T07:05:26Z
# 7    01-03-gigasecond-DainaBulmeistere  2022-10-16T12:08:20Z
# 8         01-01-hello-world-RawanAtoui  2022-10-15T21:54:48Z
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Input In [46], in <cell line: 4>()
#       1 # pd.json_normalize(data, 'locations', ['date', 'number', 'name'],
#       2 #                    record_prefix='locations_')
# ----> 4 dfn = pd.json_normalize('github_repos_with_users.json', 'mentionableUsers')
#       5 dfn
#
# File /nix/store/9qxl4vb1cmnc10bnj813y2iima4aybai-python3.10-pandas-1.4.3/lib/python3.10/site-packages/pandas/io/json/_normalize.py:443, in _json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     441     data = list(data)
#     442 else:
# --> 443     raise NotImplementedError
#     445 # check to see if a simple recursive function is possible to
#     446 # improve performance (see #15621) but only for cases such
#     447 # as pd.Dataframe(data) or pd.Dataframe(data, sep)
#     448 if (
#     449     record_path is None
#     450     and meta is None
#    (...)
#     453     and max_level is None
#     454 ):
#
# NotImplementedError:

# %%
with open('github_repos_with_users.json') as json_file:
    data = json.load(json_file)

# %%
df = pd.json_normalize(data, record_path='mentionableUsers', meta=['name', 'updatedAt', 'url'], record_prefix='user_')

# %%
df = df[df.user_login != 'dominikb1888']
df = df[df.user_login != 'ProfEnergyHuber']

# %%
# df.apply(lambda x: x['Formula'].replace('Length', str(x['Length'])), axis=1)

# Remove String 'user_login' from 'name'
df
# Out:
#                  user_id           user_login                      user_name  \
# 2           U_kgDOBuLWrg        TobiasLechner
# 5           U_kgDOBuL9Yw             Sara-256
# 8           U_kgDOBuL9Yw             Sara-256
# 11          U_kgDOBukxJg              Elyastk
# 14          U_kgDOBukxJg              Elyastk
# 17          U_kgDOBuf9WQ       Favourmekowulu
# 20          U_kgDOBuLasQ              Nazek23
# 23          U_kgDOBuLcTA     DainaBulmeistere
# 26          U_kgDOBuLbvA           RawanAtoui
# 29          U_kgDOBuLbGA  Piromya-Chaekratoke
# 32          U_kgDOBuLaoQ           maryam0109
# 35          U_kgDOBuLaoQ           maryam0109
# 38          U_kgDOBuVfLw       Alexandra18636
# 41          U_kgDOBuLYPw              mm13177
# 44          U_kgDOBuLYPw              mm13177
# 47          U_kgDOBuLQ1Q     Christabel-Oreva
# 50          U_kgDOBuLWrg        TobiasLechner
# 53          U_kgDOBuX0WQ      shreeja-shreeja
# 56          U_kgDOBuX0WQ      shreeja-shreeja
# 59          U_kgDOBuYAJA      FadyAbdelmaseeh  Fady Raafat Kamel Abdelmaseeh
# 62          U_kgDOBub0wA              reem-ab
# 65          U_kgDOBuWxag          marina20158
# 68          U_kgDOBuL1cQ               wijube
# 71          U_kgDOBuL1cQ               wijube
# 74          U_kgDOBuLcTA     DainaBulmeistere
# 77          U_kgDOBuX0WQ      shreeja-shreeja
# 80          U_kgDOBuMVIA          Jane-Amollo
# 82  MDQ6VXNlcjI3Nzg3OTI4      FadyRaafatKamel
# 86          U_kgDOBuX0WQ      shreeja-shreeja
# 89          U_kgDOBuLogA         atulmallik14
#
#                                   name             updatedAt  \
# 2         02-02-triangle-TobiasLechner  2022-10-17T11:16:32Z
# 5                  01-02-leap-Sara-256  2022-10-17T00:52:45Z
# 8           01-01-hello-world-Sara-256  2022-10-11T09:08:01Z
# 11                  01-02-leap-Elyastk  2022-10-16T21:35:14Z
# 14           01-01-hello-world-Elyastk  2022-10-16T18:35:37Z
# 17    01-01-hello-world-Favourmekowulu  2022-10-16T14:59:16Z
# 20           01-01-hello-world-Nazek23  2022-10-11T07:05:26Z
# 23   01-03-gigasecond-DainaBulmeistere  2022-10-16T12:08:20Z
